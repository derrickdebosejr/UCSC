# %%
# %matplotlib inline

# %% [markdown]
# # CMPS 140

# %% [markdown]
# ## Assignment 5
#
# **DUE: Sunday July 28, 2018 11:59pm**
#
# Turn in the assignment via Canvas.
#
# To write legible answers you will need to be familiar with both [Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet) and [Latex](https://www.latex-tutorial.com/tutorials/amsmath/)
#
# Before you turn this problem in, make sure everything runs as expected. First, restart the kernel (in the menubar, select Kernel→→Restart) and then run all cells (in the menubar, select Cell→→Run All).
#
# Make sure you fill in any place that says "YOUR CODE HERE" or "YOUR ANSWER HERE", as well as your name below:

# %%
NAME = "Derrick DeBose"

# %% [markdown]
# ## Deep Learning Model
#
# The dataset below is the same one you created a logistic regression model for in Assignment 4, in which you found that logistic regression has the fatal flaw that it is limited to a linear decision boundary. Datasets for which the two classes are not linearly seperable can never attain 100% accuracy, as you've seen.
#
# Deep learning to the rescue! In this assignment you'll create a neural network to solve this classification problem, and your deep learning model will be able to attain close to 100% accuracy. Neural networks are capable of learning highly non-linear decision boundaries.
#
# We'll construct a simple neural network to solve this problem using Keras. The final layer of the neural network will consist of a single node with a sigmoid activation function that signifies the probability of being in one class vs the other. This simple NN will outperform your logistic regression model.
#
# Your job will then be to create your own deeper neural network that can solve this classification problem perfectly.
#
# But first, we'll create a test set, by using the same parameters as above when we generated the training set, but using a different seed. Then our training and test sets will be drawn from the same distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from pylab import rcParams

# Create the training data
np.random.seed(42) 
data, labels = make_moons(n_samples=500, noise=0.1)
colors = ['r' if y else 'b' for y in labels]
print('data.shape =', data.shape)
print('labels.shape =', labels.shape)
plt.scatter(data[:,0], data[:,1], c=colors)
plt.show()
# Out:
# data.shape = (500, 2)
# labels.shape = (500,)

# %%
# Create the test data
np.random.seed(17)   
test_data, test_labels = make_moons(n_samples=500, noise=0.1)
colors = ['r' if y else 'b' for y in test_labels]
print('test_data.shape =', test_data.shape)
print('test_labels.shape =', test_labels.shape)
plt.scatter(test_data[:,0], test_data[:,1], c=colors)
plt.show()
# Out:
# test_data.shape = (500, 2)
# test_labels.shape = (500,)

# %% [markdown]
# The above image is created by sampling from the same distribution as before. But these are entirely different points than your model was trained on.  So how our model performs on this test data will be a good indication of our model's ability to generalize.
#
# In the following code, we create and train a simple neural network. After this, you'll have to create one yourself!

# %%
# We'll import Keras from TensorFlow, a simple and useful way to construct neural nets.
from tensorflow import keras

# Some useful functions we'll need
Dense = keras.layers.Dense
Sequential = keras.Sequential

# The warnings generated can be a nuisance, so we'll turn them off.
import warnings  
warnings.filterwarnings('ignore')

#                                       #
# Construct a simple neural net model   #
#                                       #
model = Sequential()

# The first hidden layer is a densly connected layer with 3 neurons, 
# with the relu activation function.
model.add(Dense(3, activation='relu'))

# The second hidden layer is a densly connected layer with 2 neurons, 
# with the relu activation function.
model.add(Dense(2, activation='relu'))

# The output layer is a single neuron with the sigmoid activation function.
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the NN model, defining the optimizer to use, the loss function, and the metrics to use.
# These settings are appropriate for a binary classification task.

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model, iterating on the data in batches of 32 samples
history = model.fit(data, labels, 
                    validation_split = 0.2, 
                    epochs = 300, 
                    batch_size = 50)

# Evaluate the model's performance
train_loss, train_acc = model.evaluate(data, labels)
test_loss, test_acc = model.evaluate(test_data, test_labels)

print('Training set accuracy:', train_acc)
print('Test set accuracy:', test_acc)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 1s 23ms/step - loss: 0.6680 - accuracy: 0.6150 - val_loss: 0.6337 - val_accuracy: 0.7000
# Epoch 2/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6564 - accuracy: 0.6225 - val_loss: 0.6260 - val_accuracy: 0.7000
# Epoch 3/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6461 - accuracy: 0.6275 - val_loss: 0.6193 - val_accuracy: 0.7000
# Epoch 4/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6363 - accuracy: 0.6375 - val_loss: 0.6133 - val_accuracy: 0.6700
# Epoch 5/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6272 - accuracy: 0.6400 - val_loss: 0.6075 - val_accuracy: 0.6800
# Epoch 6/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6187 - accuracy: 0.6525 - val_loss: 0.6019 - val_accuracy: 0.6700
# Epoch 7/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6102 - accuracy: 0.6675 - val_loss: 0.5964 - val_accuracy: 0.6800
# Epoch 8/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6022 - accuracy: 0.6775 - val_loss: 0.5909 - val_accuracy: 0.7000
# Epoch 9/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5947 - accuracy: 0.6825 - val_loss: 0.5850 - val_accuracy: 0.7100
# Epoch 10/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5870 - accuracy: 0.7000 - val_loss: 0.5792 - val_accuracy: 0.7000
# Epoch 11/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5790 - accuracy: 0.7150 - val_loss: 0.5732 - val_accuracy: 0.7200
# Epoch 12/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5716 - accuracy: 0.7175 - val_loss: 0.5670 - val_accuracy: 0.7400
# Epoch 13/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5639 - accuracy: 0.7300 - val_loss: 0.5607 - val_accuracy: 0.7400
# Epoch 14/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5563 - accuracy: 0.7425 - val_loss: 0.5541 - val_accuracy: 0.7500
# Epoch 15/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5484 - accuracy: 0.7500 - val_loss: 0.5472 - val_accuracy: 0.7500
# Epoch 16/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5403 - accuracy: 0.7650 - val_loss: 0.5399 - val_accuracy: 0.7800
# Epoch 17/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5321 - accuracy: 0.7750 - val_loss: 0.5327 - val_accuracy: 0.8000
# Epoch 18/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5234 - accuracy: 0.7850 - val_loss: 0.5252 - val_accuracy: 0.8200
# Epoch 19/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5146 - accuracy: 0.7900 - val_loss: 0.5175 - val_accuracy: 0.8400
# Epoch 20/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5056 - accuracy: 0.7975 - val_loss: 0.5100 - val_accuracy: 0.8400
# Epoch 21/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4970 - accuracy: 0.8000 - val_loss: 0.5021 - val_accuracy: 0.8400
# Epoch 22/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4880 - accuracy: 0.8100 - val_loss: 0.4946 - val_accuracy: 0.8500
# Epoch 23/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4793 - accuracy: 0.8100 - val_loss: 0.4870 - val_accuracy: 0.8500
# Epoch 24/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4707 - accuracy: 0.8125 - val_loss: 0.4790 - val_accuracy: 0.8600
# Epoch 25/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4622 - accuracy: 0.8200 - val_loss: 0.4716 - val_accuracy: 0.8600
# Epoch 26/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4542 - accuracy: 0.8250 - val_loss: 0.4643 - val_accuracy: 0.8600
# Epoch 27/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4463 - accuracy: 0.8350 - val_loss: 0.4574 - val_accuracy: 0.8700
# Epoch 28/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4388 - accuracy: 0.8450 - val_loss: 0.4505 - val_accuracy: 0.8700
# Epoch 29/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4314 - accuracy: 0.8475 - val_loss: 0.4436 - val_accuracy: 0.8700
# Epoch 30/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4242 - accuracy: 0.8575 - val_loss: 0.4371 - val_accuracy: 0.8700
# Epoch 31/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4170 - accuracy: 0.8600 - val_loss: 0.4306 - val_accuracy: 0.8700
# Epoch 32/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4101 - accuracy: 0.8650 - val_loss: 0.4240 - val_accuracy: 0.8700
# Epoch 33/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4035 - accuracy: 0.8675 - val_loss: 0.4177 - val_accuracy: 0.8700
# Epoch 34/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3971 - accuracy: 0.8725 - val_loss: 0.4120 - val_accuracy: 0.8700
# Epoch 35/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3909 - accuracy: 0.8725 - val_loss: 0.4065 - val_accuracy: 0.8700
# Epoch 36/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3850 - accuracy: 0.8725 - val_loss: 0.4013 - val_accuracy: 0.8700
# Epoch 37/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3794 - accuracy: 0.8750 - val_loss: 0.3966 - val_accuracy: 0.8700
# Epoch 38/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3743 - accuracy: 0.8750 - val_loss: 0.3921 - val_accuracy: 0.8700
# Epoch 39/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3692 - accuracy: 0.8750 - val_loss: 0.3879 - val_accuracy: 0.8700
# Epoch 40/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3644 - accuracy: 0.8775 - val_loss: 0.3838 - val_accuracy: 0.8700
# Epoch 41/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3599 - accuracy: 0.8775 - val_loss: 0.3803 - val_accuracy: 0.8700
# Epoch 42/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3557 - accuracy: 0.8775 - val_loss: 0.3769 - val_accuracy: 0.8700
# Epoch 43/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3515 - accuracy: 0.8775 - val_loss: 0.3735 - val_accuracy: 0.8700
# Epoch 44/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3475 - accuracy: 0.8775 - val_loss: 0.3707 - val_accuracy: 0.8700
# Epoch 45/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3438 - accuracy: 0.8775 - val_loss: 0.3676 - val_accuracy: 0.8700
# Epoch 46/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3402 - accuracy: 0.8775 - val_loss: 0.3644 - val_accuracy: 0.8700
# Epoch 47/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3368 - accuracy: 0.8775 - val_loss: 0.3617 - val_accuracy: 0.8700
# Epoch 48/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3336 - accuracy: 0.8775 - val_loss: 0.3595 - val_accuracy: 0.8700
# Epoch 49/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3304 - accuracy: 0.8800 - val_loss: 0.3573 - val_accuracy: 0.8700
# Epoch 50/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3275 - accuracy: 0.8800 - val_loss: 0.3546 - val_accuracy: 0.8700
# Epoch 51/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3249 - accuracy: 0.8775 - val_loss: 0.3518 - val_accuracy: 0.8700
# Epoch 52/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3218 - accuracy: 0.8775 - val_loss: 0.3502 - val_accuracy: 0.8700
# Epoch 53/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3192 - accuracy: 0.8775 - val_loss: 0.3487 - val_accuracy: 0.8700
# Epoch 54/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3168 - accuracy: 0.8775 - val_loss: 0.3468 - val_accuracy: 0.8700
# Epoch 55/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3144 - accuracy: 0.8775 - val_loss: 0.3454 - val_accuracy: 0.8700
# Epoch 56/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3123 - accuracy: 0.8775 - val_loss: 0.3434 - val_accuracy: 0.8700
# Epoch 57/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3101 - accuracy: 0.8800 - val_loss: 0.3418 - val_accuracy: 0.8700
# Epoch 58/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3081 - accuracy: 0.8800 - val_loss: 0.3408 - val_accuracy: 0.8600
# Epoch 59/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3062 - accuracy: 0.8775 - val_loss: 0.3399 - val_accuracy: 0.8600
# Epoch 60/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3044 - accuracy: 0.8775 - val_loss: 0.3390 - val_accuracy: 0.8600
# Epoch 61/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3027 - accuracy: 0.8775 - val_loss: 0.3380 - val_accuracy: 0.8600
# Epoch 62/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3011 - accuracy: 0.8775 - val_loss: 0.3367 - val_accuracy: 0.8600
# Epoch 63/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2997 - accuracy: 0.8800 - val_loss: 0.3352 - val_accuracy: 0.8600
# Epoch 64/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2983 - accuracy: 0.8800 - val_loss: 0.3349 - val_accuracy: 0.8600
# Epoch 65/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2970 - accuracy: 0.8800 - val_loss: 0.3339 - val_accuracy: 0.8500
# Epoch 66/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2957 - accuracy: 0.8800 - val_loss: 0.3327 - val_accuracy: 0.8500
# Epoch 67/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2944 - accuracy: 0.8800 - val_loss: 0.3325 - val_accuracy: 0.8500
# Epoch 68/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2933 - accuracy: 0.8800 - val_loss: 0.3322 - val_accuracy: 0.8500
# Epoch 69/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2923 - accuracy: 0.8800 - val_loss: 0.3323 - val_accuracy: 0.8400
# Epoch 70/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2915 - accuracy: 0.8800 - val_loss: 0.3301 - val_accuracy: 0.8500
# Epoch 71/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2902 - accuracy: 0.8800 - val_loss: 0.3293 - val_accuracy: 0.8500
# Epoch 72/300
# 8/8 [==============================] - 0s 9ms/step - loss: 0.2892 - accuracy: 0.8800 - val_loss: 0.3292 - val_accuracy: 0.8500
# Epoch 73/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2884 - accuracy: 0.8800 - val_loss: 0.3287 - val_accuracy: 0.8500
# Epoch 74/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2875 - accuracy: 0.8800 - val_loss: 0.3282 - val_accuracy: 0.8500
# Epoch 75/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2867 - accuracy: 0.8800 - val_loss: 0.3282 - val_accuracy: 0.8400
# Epoch 76/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2860 - accuracy: 0.8800 - val_loss: 0.3269 - val_accuracy: 0.8500
# Epoch 77/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2851 - accuracy: 0.8775 - val_loss: 0.3263 - val_accuracy: 0.8500
# Epoch 78/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2844 - accuracy: 0.8775 - val_loss: 0.3262 - val_accuracy: 0.8500
# Epoch 79/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2836 - accuracy: 0.8800 - val_loss: 0.3262 - val_accuracy: 0.8400
# Epoch 80/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2830 - accuracy: 0.8800 - val_loss: 0.3252 - val_accuracy: 0.8500
# Epoch 81/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2823 - accuracy: 0.8750 - val_loss: 0.3250 - val_accuracy: 0.8400
# Epoch 82/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2817 - accuracy: 0.8775 - val_loss: 0.3246 - val_accuracy: 0.8400
# Epoch 83/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2811 - accuracy: 0.8775 - val_loss: 0.3243 - val_accuracy: 0.8400
# Epoch 84/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2806 - accuracy: 0.8775 - val_loss: 0.3247 - val_accuracy: 0.8400
# Epoch 85/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2801 - accuracy: 0.8775 - val_loss: 0.3255 - val_accuracy: 0.8400
# Epoch 86/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2794 - accuracy: 0.8825 - val_loss: 0.3244 - val_accuracy: 0.8400
# Epoch 87/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2789 - accuracy: 0.8825 - val_loss: 0.3228 - val_accuracy: 0.8400
# Epoch 88/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2784 - accuracy: 0.8800 - val_loss: 0.3224 - val_accuracy: 0.8400
# Epoch 89/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2782 - accuracy: 0.8800 - val_loss: 0.3233 - val_accuracy: 0.8400
# Epoch 90/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2774 - accuracy: 0.8825 - val_loss: 0.3223 - val_accuracy: 0.8400
# Epoch 91/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2771 - accuracy: 0.8800 - val_loss: 0.3211 - val_accuracy: 0.8400
# Epoch 92/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2767 - accuracy: 0.8800 - val_loss: 0.3217 - val_accuracy: 0.8400
# Epoch 93/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2762 - accuracy: 0.8800 - val_loss: 0.3211 - val_accuracy: 0.8400
# Epoch 94/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2759 - accuracy: 0.8800 - val_loss: 0.3197 - val_accuracy: 0.8400
# Epoch 95/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2754 - accuracy: 0.8800 - val_loss: 0.3199 - val_accuracy: 0.8400
# Epoch 96/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2749 - accuracy: 0.8800 - val_loss: 0.3194 - val_accuracy: 0.8400
# Epoch 97/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2746 - accuracy: 0.8800 - val_loss: 0.3199 - val_accuracy: 0.8400
# Epoch 98/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2742 - accuracy: 0.8800 - val_loss: 0.3184 - val_accuracy: 0.8400
# Epoch 99/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2737 - accuracy: 0.8800 - val_loss: 0.3188 - val_accuracy: 0.8400
# Epoch 100/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2733 - accuracy: 0.8800 - val_loss: 0.3182 - val_accuracy: 0.8400
# Epoch 101/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2730 - accuracy: 0.8800 - val_loss: 0.3169 - val_accuracy: 0.8400
# Epoch 102/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2725 - accuracy: 0.8800 - val_loss: 0.3167 - val_accuracy: 0.8400
# Epoch 103/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2721 - accuracy: 0.8800 - val_loss: 0.3152 - val_accuracy: 0.8400
# Epoch 104/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2716 - accuracy: 0.8800 - val_loss: 0.3150 - val_accuracy: 0.8400
# Epoch 105/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2711 - accuracy: 0.8800 - val_loss: 0.3152 - val_accuracy: 0.8400
# Epoch 106/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2707 - accuracy: 0.8750 - val_loss: 0.3135 - val_accuracy: 0.8400
# Epoch 107/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2702 - accuracy: 0.8750 - val_loss: 0.3121 - val_accuracy: 0.8400
# Epoch 108/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2698 - accuracy: 0.8775 - val_loss: 0.3132 - val_accuracy: 0.8400
# Epoch 109/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2694 - accuracy: 0.8750 - val_loss: 0.3118 - val_accuracy: 0.8400
# Epoch 110/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2690 - accuracy: 0.8750 - val_loss: 0.3129 - val_accuracy: 0.8400
# Epoch 111/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2684 - accuracy: 0.8750 - val_loss: 0.3131 - val_accuracy: 0.8400
# Epoch 112/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2680 - accuracy: 0.8750 - val_loss: 0.3114 - val_accuracy: 0.8400
# Epoch 113/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2676 - accuracy: 0.8750 - val_loss: 0.3100 - val_accuracy: 0.8400
# Epoch 114/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2673 - accuracy: 0.8750 - val_loss: 0.3085 - val_accuracy: 0.8400
# Epoch 115/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2667 - accuracy: 0.8775 - val_loss: 0.3085 - val_accuracy: 0.8400
# Epoch 116/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2666 - accuracy: 0.8750 - val_loss: 0.3069 - val_accuracy: 0.8400
# Epoch 117/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2659 - accuracy: 0.8725 - val_loss: 0.3081 - val_accuracy: 0.8400
# Epoch 118/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2655 - accuracy: 0.8775 - val_loss: 0.3083 - val_accuracy: 0.8400
# Epoch 119/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2653 - accuracy: 0.8750 - val_loss: 0.3090 - val_accuracy: 0.8400
# Epoch 120/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2648 - accuracy: 0.8750 - val_loss: 0.3084 - val_accuracy: 0.8400
# Epoch 121/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2645 - accuracy: 0.8750 - val_loss: 0.3061 - val_accuracy: 0.8400
# Epoch 122/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2640 - accuracy: 0.8725 - val_loss: 0.3052 - val_accuracy: 0.8500
# Epoch 123/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2635 - accuracy: 0.8725 - val_loss: 0.3048 - val_accuracy: 0.8500
# Epoch 124/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2632 - accuracy: 0.8725 - val_loss: 0.3050 - val_accuracy: 0.8500
# Epoch 125/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2628 - accuracy: 0.8750 - val_loss: 0.3047 - val_accuracy: 0.8500
# Epoch 126/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2624 - accuracy: 0.8750 - val_loss: 0.3042 - val_accuracy: 0.8500
# Epoch 127/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2623 - accuracy: 0.8775 - val_loss: 0.3028 - val_accuracy: 0.8500
# Epoch 128/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2618 - accuracy: 0.8775 - val_loss: 0.3020 - val_accuracy: 0.8500
# Epoch 129/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2613 - accuracy: 0.8775 - val_loss: 0.3027 - val_accuracy: 0.8500
# Epoch 130/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2610 - accuracy: 0.8750 - val_loss: 0.3020 - val_accuracy: 0.8500
# Epoch 131/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2607 - accuracy: 0.8800 - val_loss: 0.3028 - val_accuracy: 0.8600
# Epoch 132/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2602 - accuracy: 0.8800 - val_loss: 0.3021 - val_accuracy: 0.8500
# Epoch 133/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2600 - accuracy: 0.8775 - val_loss: 0.3002 - val_accuracy: 0.8500
# Epoch 134/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2595 - accuracy: 0.8750 - val_loss: 0.3010 - val_accuracy: 0.8500
# Epoch 135/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2590 - accuracy: 0.8750 - val_loss: 0.2996 - val_accuracy: 0.8500
# Epoch 136/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2585 - accuracy: 0.8750 - val_loss: 0.2986 - val_accuracy: 0.8400
# Epoch 137/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2582 - accuracy: 0.8750 - val_loss: 0.2976 - val_accuracy: 0.8400
# Epoch 138/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2577 - accuracy: 0.8775 - val_loss: 0.2969 - val_accuracy: 0.8400
# Epoch 139/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2572 - accuracy: 0.8775 - val_loss: 0.2966 - val_accuracy: 0.8400
# Epoch 140/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2570 - accuracy: 0.8775 - val_loss: 0.2969 - val_accuracy: 0.8400
# Epoch 141/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2566 - accuracy: 0.8750 - val_loss: 0.2972 - val_accuracy: 0.8400
# Epoch 142/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2563 - accuracy: 0.8750 - val_loss: 0.2981 - val_accuracy: 0.8500
# Epoch 143/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2562 - accuracy: 0.8750 - val_loss: 0.2958 - val_accuracy: 0.8400
# Epoch 144/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2556 - accuracy: 0.8750 - val_loss: 0.2956 - val_accuracy: 0.8400
# Epoch 145/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2554 - accuracy: 0.8750 - val_loss: 0.2948 - val_accuracy: 0.8400
# Epoch 146/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2550 - accuracy: 0.8750 - val_loss: 0.2958 - val_accuracy: 0.8400
# Epoch 147/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2546 - accuracy: 0.8750 - val_loss: 0.2959 - val_accuracy: 0.8400
# Epoch 148/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2545 - accuracy: 0.8750 - val_loss: 0.2968 - val_accuracy: 0.8400
# Epoch 149/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2541 - accuracy: 0.8750 - val_loss: 0.2950 - val_accuracy: 0.8400
# Epoch 150/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.
300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2404 - accuracy: 0.8825 - val_loss: 0.2771 - val_accuracy: 0.8500
# Epoch 242/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2404 - accuracy: 0.8800 - val_loss: 0.2755 - val_accuracy: 0.8500
# Epoch 243/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2405 - accuracy: 0.8825 - val_loss: 0.2762 - val_accuracy: 0.8500
# Epoch 244/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2402 - accuracy: 0.8825 - val_loss: 0.2769 - val_accuracy: 0.8500
# Epoch 245/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2400 - accuracy: 0.8825 - val_loss: 0.2755 - val_accuracy: 0.8500
# Epoch 246/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2400 - accuracy: 0.8800 - val_loss: 0.2745 - val_accuracy: 0.8500
# Epoch 247/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2399 - accuracy: 0.8800 - val_loss: 0.2736 - val_accuracy: 0.8500
# Epoch 248/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2397 - accuracy: 0.8800 - val_loss: 0.2747 - val_accuracy: 0.8500
# Epoch 249/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2396 - accuracy: 0.8825 - val_loss: 0.2756 - val_accuracy: 0.8500
# Epoch 250/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2395 - accuracy: 0.8825 - val_loss: 0.2761 - val_accuracy: 0.8500
# Epoch 251/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2396 - accuracy: 0.8800 - val_loss: 0.2749 - val_accuracy: 0.8500
# Epoch 252/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2393 - accuracy: 0.8800 - val_loss: 0.2749 - val_accuracy: 0.8500
# Epoch 253/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2392 - accuracy: 0.8800 - val_loss: 0.2747 - val_accuracy: 0.8500
# Epoch 254/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2393 - accuracy: 0.8800 - val_loss: 0.2766 - val_accuracy: 0.8500
# Epoch 255/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2397 - accuracy: 0.8800 - val_loss: 0.2731 - val_accuracy: 0.8500
# Epoch 256/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2389 - accuracy: 0.8800 - val_loss: 0.2736 - val_accuracy: 0.8500
# Epoch 257/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2388 - accuracy: 0.8800 - val_loss: 0.2756 - val_accuracy: 0.8500
# Epoch 258/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2387 - accuracy: 0.8825 - val_loss: 0.2754 - val_accuracy: 0.8500
# Epoch 259/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2386 - accuracy: 0.8825 - val_loss: 0.2754 - val_accuracy: 0.8500
# Epoch 260/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2386 - accuracy: 0.8825 - val_loss: 0.2750 - val_accuracy: 0.8500
# Epoch 261/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2384 - accuracy: 0.8825 - val_loss: 0.2750 - val_accuracy: 0.8500
# Epoch 262/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2386 - accuracy: 0.8800 - val_loss: 0.2723 - val_accuracy: 0.8500
# Epoch 263/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2389 - accuracy: 0.8825 - val_loss: 0.2754 - val_accuracy: 0.8500
# Epoch 264/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2384 - accuracy: 0.8800 - val_loss: 0.2731 - val_accuracy: 0.8500
# Epoch 265/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2381 - accuracy: 0.8800 - val_loss: 0.2731 - val_accuracy: 0.8500
# Epoch 266/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2379 - accuracy: 0.8800 - val_loss: 0.2734 - val_accuracy: 0.8500
# Epoch 267/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2378 - accuracy: 0.8800 - val_loss: 0.2742 - val_accuracy: 0.8500
# Epoch 268/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2377 - accuracy: 0.8800 - val_loss: 0.2736 - val_accuracy: 0.8500
# Epoch 269/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2375 - accuracy: 0.8800 - val_loss: 0.2737 - val_accuracy: 0.8500
# Epoch 270/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2376 - accuracy: 0.8825 - val_loss: 0.2744 - val_accuracy: 0.8500
# Epoch 271/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2375 - accuracy: 0.8800 - val_loss: 0.2722 - val_accuracy: 0.8500
# Epoch 272/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2542 - accuracy: 0.8820
# Training set accuracy: 0.8740000128746033
# Test set accuracy: 0.8820000290870667

# %% [markdown]
# Note the last line of the above output - this simple model achieved a test set accuracy of 89% which is an improvement over the logistic regression model you created in Assignment 4.
#
# Let's next look at a summary of this model, and some training plots.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 3)                 9
#
#  dense_13 (Dense)            (None, 2)                 8
#
#  dense_14 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________

# %%
# The history of our accuracy during training.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Number of epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# The history of our cross-entropy loss during training.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Number of epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# Even this very simple neural network with only 3 neurons in it's first hidden layer, 2 in it's second, and a single neuron in the output layer was able to achieve better results than we could attain with logistic regression. You'll create a better neural net model, one that attains very close to 100% accuracy on the test set. But first, the following code will allow us to visualize our deep neural network's decision boundary.
#
# This will take a moment to construct the plot.

# %%
#
# This code is substantively from https://rohitmidha23.github.io/Neural-Network-Decision-Boundary/
#
def plot_decision_boundary(X, y, model, steps=1000, cmap='bwr'):
    # The following allows you to adjust the plot size
    rcParams['figure.figsize'] = 8, 6  # 8 inches by 6 inches
    cmap = plt.get_cmap(cmap)

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min() - 1, X[:,0].max() + 1
    ymin, ymax = X[:,1].min() - 1, X[:,1].max() + 1
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])

    # Plot decision boundary in region of interest
    z = labels.reshape(xx.shape)

    fig, ax = plt.subplots()
    ax.contourf(xx, yy, z, cmap=cmap, alpha=0.5)

    # Get predicted labels on training data and plot
    train_labels = model.predict(X)
    ax.scatter(X[:,0], X[:,1], c=y, cmap=cmap, lw=0)

    return fig, ax

plot_decision_boundary(test_data, test_labels, model) 
# Reset figure size back to default.
rcParams['figure.figsize'] = 6, 4
# Out:
# 31250/31250 [==============================] - 36s 1ms/step
# 16/16 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Problem 1
#
# The above seems to be underfitting. Our neural network was just too simple to be capable of learning to discriminate this data, though it does a bit better than logistic regression. The solution is a larger and deeper neural network.

# %% [markdown]
# ### (a) ###
# Create a neural network with more nodes per layer, and more layers, that attains as close to 100% accuracy as possible on the test set. Don't be afraid to experiment with much larger networks with more nodes per layer and more layers.

# %%
### YOUR CODE HERE ###



#                                       #
# Construct a simple neural net model   #
#                                       #
model = Sequential()

# The first hidden layer is a densly connected layer with 100 neurons, 
# with the relu activation function.
model.add(Dense(100, activation='relu'))

# The second hidden layer is a densly connected layer with 75 neurons, 
# with the relu activation function.
model.add(Dense(75, activation='relu'))

# The third hidden layer is a densly connected layer with 75 neurons, 
# with the relu activation function.
model.add(Dense(75, activation='relu'))

# The fouth hidden layer is a the sigmoid activation function with 30 neurons.
model.add(Dense(30, activation='sigmoid'))

# The output layer is a single neuron with the sigmoid activation function.
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### (b) ###
# Compile and train the NN model, defining the optimizer to use, the loss function,
# and the metrics to use.

# %%
### YOUR CODE HERE ###
# Compile the NN model, defining the optimizer to use, the loss function, and the metrics to use.
# These settings are appropriate for a binary classification task.

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model, iterating on the data in batches of 32 samples
history = model.fit(data, labels, 
                    validation_split = 0.2, 
                    epochs = 300, 
                    batch_size = 50)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 1s 25ms/step - loss: 0.6927 - accuracy: 0.4875 - val_loss: 0.6568 - val_accuracy: 0.5500
# Epoch 2/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6461 - accuracy: 0.5800 - val_loss: 0.6077 - val_accuracy: 0.8100
# Epoch 3/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5745 - accuracy: 0.8350 - val_loss: 0.5236 - val_accuracy: 0.8400
# Epoch 4/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4722 - accuracy: 0.8275 - val_loss: 0.4225 - val_accuracy: 0.8500
# Epoch 5/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3685 - accuracy: 0.8475 - val_loss: 0.3542 - val_accuracy: 0.8600
# Epoch 6/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3064 - accuracy: 0.8675 - val_loss: 0.3355 - val_accuracy: 0.8500
# Epoch 7/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2816 - accuracy: 0.8800 - val_loss: 0.3211 - val_accuracy: 0.8400
# Epoch 8/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2720 - accuracy: 0.8750 - val_loss: 0.2922 - val_accuracy: 0.8600
# Epoch 9/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2511 - accuracy: 0.8875 - val_loss: 0.3248 - val_accuracy: 0.8400
# Epoch 10/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2459 - accuracy: 0.8925 - val_loss: 0.2678 - val_accuracy: 0.8700
# Epoch 11/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2291 - accuracy: 0.9000 - val_loss: 0.2684 - val_accuracy: 0.8600
# Epoch 12/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2164 - accuracy: 0.9050 - val_loss: 0.2583 - val_accuracy: 0.8600
# Epoch 13/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2040 - accuracy: 0.9025 - val_loss: 0.2233 - val_accuracy: 0.8900
# Epoch 14/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1889 - accuracy: 0.9300 - val_loss: 0.2063 - val_accuracy: 0.9100
# Epoch 15/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1744 - accuracy: 0.9325 - val_loss: 0.1968 - val_accuracy: 0.9100
# Epoch 16/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1576 - accuracy: 0.9500 - val_loss: 0.1779 - val_accuracy: 0.9100
# Epoch 17/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1414 - accuracy: 0.9475 - val_loss: 0.1646 - val_accuracy: 0.9300
# Epoch 18/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1318 - accuracy: 0.9500 - val_loss: 0.1438 - val_accuracy: 0.9500
# Epoch 19/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1115 - accuracy: 0.9600 - val_loss: 0.1435 - val_accuracy: 0.9400
# Epoch 20/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1001 - accuracy: 0.9625 - val_loss: 0.1092 - val_accuracy: 0.9600
# Epoch 21/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0896 - accuracy: 0.9700 - val_loss: 0.0969 - val_accuracy: 0.9600
# Epoch 22/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0766 - accuracy: 0.9725 - val_loss: 0.0806 - val_accuracy: 0.9800
# Epoch 23/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0685 - accuracy: 0.9750 - val_loss: 0.0795 - val_accuracy: 0.9600
# Epoch 24/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0591 - accuracy: 0.9800 - val_loss: 0.0588 - val_accuracy: 0.9800
# Epoch 25/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0482 - accuracy: 0.9875 - val_loss: 0.0704 - val_accuracy: 0.9700
# Epoch 26/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0434 - accuracy: 0.9950 - val_loss: 0.0452 - val_accuracy: 0.9900
# Epoch 27/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0364 - accuracy: 0.9950 - val_loss: 0.0486 - val_accuracy: 0.9900
# Epoch 28/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0328 - accuracy: 0.9950 - val_loss: 0.0353 - val_accuracy: 0.9900
# Epoch 29/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0279 - accuracy: 0.9975 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 30/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 31/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 32/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 33/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 1.0000
# Epoch 34/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 35/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 36/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 1.0000
# Epoch 37/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 38/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 39/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 40/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 41/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 42/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 43/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 44/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 45/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 46/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 47/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 48/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 49/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 50/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 51/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 52/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 53/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 54/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 55/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 56/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 57/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 58/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 59/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 60/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 61/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 62/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 63/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 64/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 65/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 66/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 67/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 68/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 69/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 70/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 71/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 72/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 73/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 74/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 75/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 76/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 77/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 78/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 79/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 80/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 81/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 82/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 83/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 84/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 85/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 86/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 87/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 88/300
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 89/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 90/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 91/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 92/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 93/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 94/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 95/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 96/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 97/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 98/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 99/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 100/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 101/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 102/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 103/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 104/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 105/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 106/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 107/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 108/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 109/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 110/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 111/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 112/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 113/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 114/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 115/300
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 116/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 117/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 118/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 119/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 120/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 121/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 122/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 123/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 124/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 125/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 126/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 127/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 128/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 129/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 130/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 131/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 132/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 133/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 134/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 135/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 136/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 137/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 138/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 139/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 140/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 141/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 142/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 143/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 144/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 145/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 146/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 147/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 148/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 149/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 150/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 151/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 152/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 153/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 154/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 155/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 156/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 157/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 158/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 159/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 160/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 161/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 162/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 163/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 164/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 165/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 166/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 167/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 168/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 169/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 170/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 171/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 172/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 173/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 174/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 175/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 176/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 177/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 178/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 179/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 180/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 181/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 182/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 183/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 184/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 185/300
# 8/8 [==============================] - 0s 6ms/step - loss: 9.9861e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 186/300
# 8/8 [==============================] - 0s 5ms/step - loss: 9.8972e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 187/300
# 8/8 [==============================] - 0s 6ms/step - loss: 9.8086e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 188/300
# 8/8 [==============================] - 0s 6ms/step - loss: 9.7218e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 189/300
# 8/8 [==============================] - 0s 5ms/step - loss: 9.6358e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 190/300
# 8/8 [==============================] - 0s 6ms/step - loss: 9.5507e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 191/300
# 8/8 [==============================] - 0s 6ms/step - loss: 9.4670e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch
# 8/8 [==============================] - 0s 5ms/step - loss: 4.7054e-04 - accuracy: 1.0000 - val_loss: 4.9812e-04 - val_accuracy: 1.0000
# Epoch 284/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.6742e-04 - accuracy: 1.0000 - val_loss: 4.9474e-04 - val_accuracy: 1.0000
# Epoch 285/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.6434e-04 - accuracy: 1.0000 - val_loss: 4.9138e-04 - val_accuracy: 1.0000
# Epoch 286/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.6124e-04 - accuracy: 1.0000 - val_loss: 4.8808e-04 - val_accuracy: 1.0000
# Epoch 287/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.5820e-04 - accuracy: 1.0000 - val_loss: 4.8470e-04 - val_accuracy: 1.0000
# Epoch 288/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.5518e-04 - accuracy: 1.0000 - val_loss: 4.8154e-04 - val_accuracy: 1.0000
# Epoch 289/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.5220e-04 - accuracy: 1.0000 - val_loss: 4.7869e-04 - val_accuracy: 1.0000
# Epoch 290/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.4921e-04 - accuracy: 1.0000 - val_loss: 4.7512e-04 - val_accuracy: 1.0000
# Epoch 291/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.4629e-04 - accuracy: 1.0000 - val_loss: 4.7172e-04 - val_accuracy: 1.0000
# Epoch 292/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.4337e-04 - accuracy: 1.0000 - val_loss: 4.6885e-04 - val_accuracy: 1.0000
# Epoch 293/300
# 8/8 [==============================] - 0s 8ms/step - loss: 4.4050e-04 - accuracy: 1.0000 - val_loss: 4.6549e-04 - val_accuracy: 1.0000
# Epoch 294/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.3761e-04 - accuracy: 1.0000 - val_loss: 4.6282e-04 - val_accuracy: 1.0000
# Epoch 295/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.3476e-04 - accuracy: 1.0000 - val_loss: 4.5988e-04 - val_accuracy: 1.0000
# Epoch 296/300
# 8/8 [==============================] - 0s 7ms/step - loss: 4.3196e-04 - accuracy: 1.0000 - val_loss: 4.5686e-04 - val_accuracy: 1.0000
# Epoch 297/300
# 8/8 [==============================] - 0s 7ms/step - loss: 4.2918e-04 - accuracy: 1.0000 - val_loss: 4.5427e-04 - val_accuracy: 1.0000
# Epoch 298/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.2636e-04 - accuracy: 1.0000 - val_loss: 4.5111e-04 - val_accuracy: 1.0000
# Epoch 299/300
# 8/8 [==============================] - 0s 6ms/step - loss: 4.2362e-04 - accuracy: 1.0000 - val_loss: 4.4793e-04 - val_accuracy: 1.0000
# Epoch 300/300
# 8/8 [==============================] - 0s 9ms/step - loss: 4.2090e-04 - accuracy: 1.0000 - val_loss: 4.4510e-04 - val_accuracy: 1.0000

# %% [markdown]
# ### (c) ###
# What was your final testset accuracy?

# %%
# Evaluate the model's performance
train_loss, train_acc = model.evaluate(data, labels)
test_loss, test_acc = model.evaluate(test_data, test_labels)
print('Training set accuracy:', train_acc)
print('Test set accuracy:', test_acc)
# Out:
# 16/16 [==============================] - 0s 2ms/step - loss: 4.2452e-04 - accuracy: 1.0000
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Training set accuracy: 1.0
# Test set accuracy: 1.0

# %% [markdown]
# ####Training set accuracy: 1.0
# ####Test set accuracy: 0.998

# %% [markdown]
# ### (d) ###
# Create a summary of your model.

# %%
### YOUR CODE HERE ###
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 100)               300
#
#  dense_16 (Dense)            (None, 75)                7575
#
#  dense_17 (Dense)            (None, 75)                5700
#
#  dense_18 (Dense)            (None, 30)                2280
#
#  dense_19 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 15,886
# Trainable params: 15,886
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (e) ###
# How many parameters does your model have?

# %% [markdown]
# ## 15,886

# %% [markdown]
# ### (f) ###
# Plot the learning curves for your model, one for accuracy and the other for cross-entropy loss.

# %%
### YOUR CODE HERE ###
# The history of our accuracy during training.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Number of epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# The history of our cross-entropy loss during training.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Number of epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# ### (g) ###
# Plot your model's decision boundary.

# %%
### YOUR CODE HERE ###
plot_decision_boundary(test_data, test_labels, model) 
# Reset figure size back to default.
rcParams['figure.figsize'] = 6, 4
# Out:
# 31250/31250 [==============================] - 41s 1ms/step
# 16/16 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Noisier Data

# %% [markdown]
# Next you'll retrain your neural network on the following noiser data. This time even a neural network model won't be able to attain 100% accuracy.

# %%
# Create the training data
np.random.seed(137) 
data, labels = make_moons(n_samples=500, noise=0.2)
colors = ['r' if y else 'b' for y in labels]
print('data.shape =', data.shape)
print('labels.shape =', labels.shape)
plt.scatter(data[:,0], data[:,1], c=colors)
plt.show()
# Out:
# data.shape = (500, 2)
# labels.shape = (500,)

# %%
# Create the test data
np.random.seed(17)   
test_data, test_labels = make_moons(n_samples=500, noise=0.2)
colors = ['r' if y else 'b' for y in test_labels]
print('test_data.shape =', test_data.shape)
print('test_labels.shape =', test_labels.shape)
plt.scatter(test_data[:,0], test_data[:,1], c=colors)
plt.show()
# Out:
# test_data.shape = (500, 2)
# test_labels.shape = (500,)

# %% [markdown]
# ## Problem 2
#
# ## (a)
# Your model is already defined, so copy your code from 1(b) above and retrain your model on this new, noiser data.

# %%
# Compile the NN model, defining the optimizer to use, the loss function, and the metrics to use.
# These settings are appropriate for a binary classification task.

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model, iterating on the data in batches of 32 samples
history = model.fit(data, labels, 
                    validation_split = 0.2, 
                    epochs = 300, 
                    batch_size = 50)

# Evaluate the model's performance
train_loss, train_acc = model.evaluate(data, labels)
test_loss, test_acc = model.evaluate(test_data, test_labels)
print('Training set accuracy:', train_acc)
print('Test set accuracy:', test_acc)
# Out:
# Epoch 1/300
# 8/8 [==============================] - 1s 60ms/step - loss: 0.1554 - accuracy: 0.9650 - val_loss: 0.0620 - val_accuracy: 0.9900
# Epoch 2/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1527 - accuracy: 0.9675 - val_loss: 0.0667 - val_accuracy: 0.9900
# Epoch 3/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.
300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0561 - accuracy: 0.9775 - val_loss: 0.0746 - val_accuracy: 0.9900
# Epoch 279/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0556 - accuracy: 0.9750 - val_loss: 0.0733 - val_accuracy: 0.9900
# Epoch 280/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0565 - accuracy: 0.9775 - val_loss: 0.0774 - val_accuracy: 0.9900
# Epoch 281/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0576 - accuracy: 0.9775 - val_loss: 0.0788 - val_accuracy: 0.9900
# Epoch 282/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0590 - accuracy: 0.9750 - val_loss: 0.0711 - val_accuracy: 0.9900
# Epoch 283/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0570 - accuracy: 0.9750 - val_loss: 0.0778 - val_accuracy: 0.9900
# Epoch 284/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0564 - accuracy: 0.9775 - val_loss: 0.0701 - val_accuracy: 0.9900
# Epoch 285/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0561 - accuracy: 0.9750 - val_loss: 0.0763 - val_accuracy: 0.9900
# Epoch 286/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0557 - accuracy: 0.9775 - val_loss: 0.0744 - val_accuracy: 0.9900
# Epoch 287/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0574 - accuracy: 0.9725 - val_loss: 0.0737 - val_accuracy: 0.9900
# Epoch 288/300
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0548 - accuracy: 0.9775 - val_loss: 0.0767 - val_accuracy: 0.9900
# Epoch 289/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0562 - accuracy: 0.9775 - val_loss: 0.0748 - val_accuracy: 0.9900
# Epoch 290/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9775 - val_loss: 0.0750 - val_accuracy: 0.9900
# Epoch 291/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0548 - accuracy: 0.9750 - val_loss: 0.0748 - val_accuracy: 0.9900
# Epoch 292/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0555 - accuracy: 0.9775 - val_loss: 0.0766 - val_accuracy: 0.9900
# Epoch 293/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0546 - accuracy: 0.9775 - val_loss: 0.0744 - val_accuracy: 0.9900
# Epoch 294/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0551 - accuracy: 0.9750 - val_loss: 0.0759 - val_accuracy: 0.9900
# Epoch 295/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0558 - accuracy: 0.9750 - val_loss: 0.0731 - val_accuracy: 0.9900
# Epoch 296/300
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0555 - accuracy: 0.9750 - val_loss: 0.0761 - val_accuracy: 0.9900
# Epoch 297/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0545 - accuracy: 0.9775 - val_loss: 0.0778 - val_accuracy: 0.9900
# Epoch 298/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0544 - accuracy: 0.9775 - val_loss: 0.0759 - val_accuracy: 0.9900
# Epoch 299/300
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0546 - accuracy: 0.9750 - val_loss: 0.0742 - val_accuracy: 0.9900
# Epoch 300/300
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0540 - accuracy: 0.9750 - val_loss: 0.0770 - val_accuracy: 0.9900
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0582 - accuracy: 0.9800
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1586 - accuracy: 0.9560
# Training set accuracy: 0.9800000190734863
# Test set accuracy: 0.9559999704360962

# %% [markdown]
# ## (b)
#
# Plot your models training curves for accuracy and loss, as well as your model's decision boundary.

# %%
### YOUR CODE HERE ###

model.summary()

# The history of our accuracy during training.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Number of epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# The history of our cross-entropy loss during training.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Number of epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()


plot_decision_boundary(test_data, test_labels, model) 
# Reset figure size back to default.
rcParams['figure.figsize'] = 6, 4
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 100)               300
#
#  dense_16 (Dense)            (None, 75)                7575
#
#  dense_17 (Dense)            (None, 75)                5700
#
#  dense_18 (Dense)            (None, 30)                2280
#
#  dense_19 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 15,886
# Trainable params: 15,886
# Non-trainable params: 0
# _________________________________________________________________
# 31250/31250 [==============================] - 42s 1ms/step
# 16/16 [==============================] - 0s 2ms/step

# %% [markdown]
# ### (c) ###
# Does your model show signs of overfitting?  Please explain why you think so (one way or the other).

# %% [markdown]
# ####My model does not show signs of overfitting because there are blue dots in the red area and red dots in the blue area because the noisy data does not allow us to have a smooth function that pefectly separates the red and blue dots

# %% [markdown]
# ### (d) ###
# Does your model's training loss plot indicate that further training may yeild a slightly better accuracy?

# %% [markdown]
# #### YOUR ANSWER HERE ###

# %% [markdown]
# #### The noisy data does not allow us to have a smooth function that pefectly separates the red and blue dots so, more training will not significantly increase the accuracy. Having 100% accuracy will result in a ovefitting

# %% [markdown]
# # Cat vs. Dog Image Classification
# ## Building a Convolutional Neural Network [CNN] from Scratch
#
# In this exercise, you'll build a classifier model from scratch that is able to distinguish dogs from cats. We will follow these steps:
#
# 1. Explore the example data
# 2. Build a small convnet from scratch to solve our classification problem
# 3. Evaluate training and validation accuracy
#
# ## Explore the Example Data
# Let's start by downloading our example data, a .zip of 3,000 JPG pictures of cats and dogs, and extracting it locally in `/tmp`.

# %% [markdown]
# **NOTE:** The 3,000 images used in this exercise are excerpted from the ["Dogs vs. Cats" dataset](https://www.kaggle.com/c/dogs-vs-cats/data) available on Kaggle, which contains 25,000 images. Here, we use a subset of the full dataset to decrease training time for educational purposes.

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2022-11-01 01:26:28--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.97.128, 74.125.196.128, 74.125.31.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.97.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   146MB/s    in 0.4s
#
# 2022-11-01 01:26:28 (146 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %% [markdown]
# The contents of the .zip are extracted to the base directory `/tmp/cats_and_dogs_filtered`, which contains `train` and `validation` subdirectories for the training and validation datasets, which in turn each contain `cats` and `dogs` subdirectories. Let's define each of these directories:

# %%
base_dir = '/tmp/cats_and_dogs_filtered'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat pictures
train_cats_dir = os.path.join(train_dir, 'cats')

# Directory with our training dog pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with our validation cat pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')

# Directory with our validation dog pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %% [markdown]
# Now, let's see what the filenames look like in the `cats` and `dogs` `train` directories (file naming conventions are the same in the `validation` directory):

# %%
train_cat_fnames = os.listdir(train_cats_dir)
print(train_cat_fnames[:10])

train_dog_fnames = os.listdir(train_dogs_dir)
train_dog_fnames.sort()
print(train_dog_fnames[:10])
# Out:
# ['cat.344.jpg', 'cat.837.jpg', 'cat.857.jpg', 'cat.110.jpg', 'cat.655.jpg', 'cat.416.jpg', 'cat.422.jpg', 'cat.401.jpg', 'cat.264.jpg', 'cat.333.jpg']
# ['dog.0.jpg', 'dog.1.jpg', 'dog.10.jpg', 'dog.100.jpg', 'dog.101.jpg', 'dog.102.jpg', 'dog.103.jpg', 'dog.104.jpg', 'dog.105.jpg', 'dog.106.jpg']

# %% [markdown]
# Let's find out the total number of cat and dog images in the `train` and `validation` directories:

# %%
print('total training cat images:', len(os.listdir(train_cats_dir))) 
print('total training dog images:', len(os.listdir(train_dogs_dir))) 
print('total validation cat images:', len(os.listdir(validation_cats_dir))) 
print('total validation dog images:', len(os.listdir(validation_dogs_dir)))
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500

# %% [markdown]
# For both cats and dogs, we have 1,000 training images and 500 test images.
#
# Now let's take a look at a few pictures to get a better sense of what the cat and dog datasets look like. First, configure the matplot parameters:

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %% [markdown]
# Now, display a batch of 8 cat and 8 dog pictures. You can rerun the cell to see a fresh batch each time:

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_cat_pix = [os.path.join(train_cats_dir, fname) 
                for fname in train_cat_fnames[pic_index-8:pic_index]]
next_dog_pix = [os.path.join(train_dogs_dir, fname) 
                for fname in train_dog_fnames[pic_index-8:pic_index]]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# #### Building a Small Convnet from Scratch to Get to 72% Accuracy
#
# The images that will go into our convnet are 150x150 color images (in the next section on Data Preprocessing, we'll add handling to resize all the images to 150x150 before feeding them into the neural network).
#
# Let's code up the architecture. We will stack 3 {convolution + relu + maxpooling} modules. Our convolutions operate on 3x3 windows and our maxpooling layers operate on 2x2 windows. Our first convolution extracts 4 filters, the following one extracts 5 filters, and the last one extracts 10 filters.

# %%
# Load some neural network functions we'll be using.
from tensorflow.keras import layers
from tensorflow.keras import Model

# %%
# Our input feature map is 150x150x3: 150x150 for the image pixels, and 3 for
# the three color channels: R, G, and B
img_input = layers.Input(shape=(150, 150, 3))

# First convolution extracts 4 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(4, 3, activation='relu')(img_input)
x = layers.MaxPooling2D(2)(x)

# Second convolution extracts 5 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(5, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)

# Third convolution extracts 10 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(10, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)

# %% [markdown]
# On top of it we stick two fully-connected layers. Because we are facing a two-class classification problem, i.e. a binary classification problem, we will end our network with a sigmoid activation, so that the output of our network will be a single scalar between 0 and 1, encoding the probability that the current image is class 1 (as opposed to class 0).

# %%
# Flatten feature map to a 1-dim tensor so we can add fully connected layers
x = layers.Flatten()(x)

# Create a fully connected layer with ReLU activation and 512 hidden units
x = layers.Dense(20, activation='relu')(x)

# Create output layer with a single node and sigmoid activation
output = layers.Dense(1, activation='sigmoid')(x)

# Create model:
# input = input feature map
# output = input feature map + stacked convolution/maxpooling layers + fully 
# connected layer + sigmoid output layer
model = Model(img_input, output)

# %% [markdown]
# Let's summarize the model architecture:

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  conv2d_6 (Conv2D)           (None, 148, 148, 4)       112
#
#  max_pooling2d_6 (MaxPooling  (None, 74, 74, 4)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 72, 72, 5)         185
#
#  max_pooling2d_7 (MaxPooling  (None, 36, 36, 5)        0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 34, 34, 10)        460
#
#  max_pooling2d_8 (MaxPooling  (None, 17, 17, 10)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 2890)              0
#
#  dense_20 (Dense)            (None, 20)                57820
#
#  dense_21 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 58,598
# Trainable params: 58,598
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The "output shape" column shows how the size of your feature map evolves in each successive layer. The convolution layers reduce the size of the feature maps by a bit due to padding, and each pooling layer halves the feature map.
#
# Next, we'll configure the specifications for model training. We will train our model with the `binary_crossentropy` loss, because it's a binary classification problem and our final activation is a sigmoid. We will use the `rmsprop` optimizer with a learning rate of `0.001`. During training, we will want to monitor classification accuracy.
#
# **NOTE**: In this case, using the [RMSprop optimization algorithm](https://wikipedia.org/wiki/Stochastic_gradient_descent#RMSProp) is preferable to [stochastic gradient descent](https://developers.google.com/machine-learning/glossary/#SGD) (SGD), because RMSprop automates learning-rate tuning for us. (Other optimizers, such as [Adam](https://wikipedia.org/wiki/Stochastic_gradient_descent#Adam) and [Adagrad](https://developers.google.com/machine-learning/glossary/#AdaGrad), also automatically adapt the learning rate during training, and would work equally well here.)

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr = 0.001),
              metrics = ['acc'])

# %% [markdown]
# Let's set up data generators that will read pictures in our source folders, convert them to `float32` tensors, and feed them (with their labels) to our network. We'll have one generator for the training images and one for the validation images. Our generators will yield batches of 20 images of size 150x150 and their labels (binary).
#
# As you may already know, data that goes into neural networks should usually be normalized in some way to make it more amenable to processing by the network. (It is uncommon to feed raw pixels into a convnet.) In our case, we will preprocess our images by normalizing the pixel values to be in the `[0, 1]` range (originally all values are in the `[0, 255]` range).
#
# In Keras this can be done via the `keras.preprocessing.image.ImageDataGenerator` class using the `rescale` parameter. This `ImageDataGenerator` class allows you to instantiate generators of augmented image batches (and their labels) via `.flow(data, labels)` or `.flow_from_directory(directory)`. These generators can then be used with the Keras model methods that accept data generators as inputs: `fit_generator`, `evaluate_generator`, and `predict_generator`.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches of 20 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        train_dir,  # This is the source directory for training images
        target_size = (150, 150),  # All images will be resized to 150x150
        batch_size = 20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode = 'binary')

# Flow validation images in batches of 20 using test_datagen generator
validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size = (150, 150),
        batch_size = 20,
        class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ##### Training
# Let's train on all 2,000 images available, for 15 epochs, and validate on all 1,000 test images. (This may take a few minutes to run.)

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch = 100,  # 2000 images = batch_size * steps
      epochs = 15,
      validation_data = validation_generator,
      validation_steps = 50,  # 1000 images = batch_size * steps
      verbose = 2)
# Out:
# Epoch 1/15
# 100/100 - 33s - loss: 0.6885 - acc: 0.5410 - val_loss: 0.6837 - val_acc: 0.5290 - 33s/epoch - 329ms/step
# Epoch 2/15
# 100/100 - 31s - loss: 0.6609 - acc: 0.6210 - val_loss: 0.6680 - val_acc: 0.5670 - 31s/epoch - 312ms/step
# Epoch 3/15
# 100/100 - 31s - loss: 0.6215 - acc: 0.6625 - val_loss: 0.6269 - val_acc: 0.6750 - 31s/epoch - 313ms/step
# Epoch 4/15
# 100/100 - 33s - loss: 0.5957 - acc: 0.6730 - val_loss: 0.6353 - val_acc: 0.6610 - 33s/epoch - 327ms/step
# Epoch 5/15
# 100/100 - 31s - loss: 0.5715 - acc: 0.7035 - val_loss: 0.6271 - val_acc: 0.6720 - 31s/epoch - 314ms/step
# Epoch 6/15
# 100/100 - 31s - loss: 0.5418 - acc: 0.7310 - val_loss: 0.6210 - val_acc: 0.6660 - 31s/epoch - 314ms/step
# Epoch 7/15
# 100/100 - 31s - loss: 0.5171 - acc: 0.7440 - val_loss: 0.6302 - val_acc: 0.6760 - 31s/epoch - 314ms/step
# Epoch 8/15
# 100/100 - 31s - loss: 0.4798 - acc: 0.7690 - val_loss: 0.6264 - val_acc: 0.6800 - 31s/epoch - 314ms/step
# Epoch 9/15
# 100/100 - 33s - loss: 0.4448 - acc: 0.7950 - val_loss: 0.6696 - val_acc: 0.6670 - 33s/epoch - 328ms/step
# Epoch 10/15
# 100/100 - 31s - loss: 0.4197 - acc: 0.8140 - val_loss: 0.6590 - val_acc: 0.6730 - 31s/epoch - 313ms/step
# Epoch 11/15
# 100/100 - 31s - loss: 0.3813 - acc: 0.8255 - val_loss: 0.7510 - val_acc: 0.6680 - 31s/epoch - 314ms/step
# Epoch 12/15
# 100/100 - 32s - loss: 0.3295 - acc: 0.8545 - val_loss: 0.7964 - val_acc: 0.6580 - 32s/epoch - 316ms/step
# Epoch 13/15
# 100/100 - 32s - loss: 0.2947 - acc: 0.8805 - val_loss: 0.7512 - val_acc: 0.6630 - 32s/epoch - 318ms/step
# Epoch 14/15
# 100/100 - 32s - loss: 0.2608 - acc: 0.8890 - val_loss: 0.7873 - val_acc: 0.6730 - 32s/epoch - 318ms/step
# Epoch 15/15
# 100/100 - 32s - loss: 0.2183 - acc: 0.9190 - val_loss: 0.8793 - val_acc: 0.6830 - 32s/epoch - 318ms/step

# %% [markdown]
# Evaluating Accuracy and Loss for the Model
# Our simple CNN achieved about 70% accuracy on the validation set. Let's plot the training/validation accuracy and loss as collected during training:

# %%
# Retrieve a list of accuracy results on training and test data
# sets for each training epoch
acc = history.history['acc']
val_acc = history.history['val_acc']

# Retrieve a list of list results on training and test data
# sets for each training epoch
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs = range(len(acc))

# Plot training and validation accuracy per epoch
plt.plot(epochs, acc)
plt.plot(epochs, val_acc)
plt.legend(['train', 'test'], loc='upper left')
plt.title('Training and validation accuracy')

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss)
plt.plot(epochs, val_loss)
plt.legend(['train', 'test'], loc='lower left')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# This neural net has a serious overfitting problem!

# %% [markdown]
# ## Problem 3
#
# Create a neural network very similar to the one above, but with
#
#     16 channels in the first convolutional layer
#     32 channels in the first convolutional layer
#     64 channels in the first convolutional layer
#     512 channels in the dense layer immediately following the flattened layer.
#
# **NOTE**: This is a configuration that is widely used and known to work well for image classification. Also, since we have relatively few training examples (1,000), using just three convolutional modules keeps the model small, which lowers the risk of overfitting.

# %%
# Our input feature map is 150x150x3: 150x150 for the image pixels, and 3 for
# the three color channels: R, G, and B
img_input = layers.Input(shape=(150, 150, 3))

# First convolution extracts 16 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(16, 3, activation='relu')(img_input)
x = layers.MaxPooling2D(2)(x)

# Second convolution extracts 32 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(32, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)

# Third convolution extracts 64 filters that are 3x3
# Convolution is followed by max-pooling layer with a 2x2 window
x = layers.Conv2D(64, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)

# Flatten feature map to a 1-dim tensor so we can add fully connected layers
x = layers.Flatten()(x)

# Create a fully connected layer with ReLU activation and 512 hidden units
x = layers.Dense(20, activation='relu')(x)

# Create output layer with a single node and sigmoid activation
output = layers.Dense(1, activation='sigmoid')(x)

# Create model:
# input = input feature map
# output = input feature map + stacked convolution/maxpooling layers + fully 
# connected layer + sigmoid output layer
model = Model(img_input, output)

# %% [markdown]
# ## Problem 4
#
# ### (a)
#
# Compile your model, as before.

# %%
### YOUR CODE HERE ###
model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr = 0.001),
              metrics = ['acc'])

# %% [markdown]
# ### (b)
#
# Make a summary of this model. How many trainable parameters does this model have?

# %%
### YOUR CODE HERE ###
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  conv2d_9 (Conv2D)           (None, 148, 148, 16)      448
#
#  max_pooling2d_9 (MaxPooling  (None, 74, 74, 16)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 72, 72, 32)        4640
#
#  max_pooling2d_10 (MaxPoolin  (None, 36, 36, 32)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 34, 34, 64)        18496
#
#  max_pooling2d_11 (MaxPoolin  (None, 17, 17, 64)       0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 18496)             0
#
#  dense_22 (Dense)            (None, 20)                369940
#
#  dense_23 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 393,545
# Trainable params: 393,545
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ####This model has 393,545 trainable parameters.

# %% [markdown]
# ### (c) ###
#
# Now train your model, as before again for 15 epochs.

# %%
### YOUR CODE HERE ###
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches of 20 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        train_dir,  # This is the source directory for training images
        target_size = (150, 150),  # All images will be resized to 150x150
        batch_size = 20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode = 'binary')

# Flow validation images in batches of 20 using test_datagen generator
validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size = (150, 150),
        batch_size = 20,
        class_mode = 'binary')

history = model.fit_generator(
      train_generator,
      steps_per_epoch = 100,  # 2000 images = batch_size * steps
      epochs = 15,
      validation_data = validation_generator,
      validation_steps = 50,  # 1000 images = batch_size * steps
      verbose = 2)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Epoch 1/15
# 100/100 - 53s - loss: 0.6955 - acc: 0.4910 - val_loss: 0.6931 - val_acc: 0.5000 - 53s/epoch - 530ms/step
# Epoch 2/15
# 100/100 - 53s - loss: 0.6932 - acc: 0.4880 - val_loss: 0.6931 - val_acc: 0.5000 - 53s/epoch - 531ms/step
# Epoch 3/15
# 100/100 - 51s - loss: 0.6932 - acc: 0.4940 - val_loss: 0.6931 - val_acc: 0.5000 - 51s/epoch - 515ms/step
# Epoch 4/15
# 100/100 - 52s - loss: 0.6932 - acc: 0.4990 - val_loss: 0.6931 - val_acc: 0.5000 - 52s/epoch - 521ms/step
# Epoch 5/15
# 100/100 - 56s - loss: 0.6932 - acc: 0.4950 - val_loss: 0.6931 - val_acc: 0.5000 - 56s/epoch - 562ms/step
# Epoch 6/15
# 100/100 - 53s - loss: 0.6932 - acc: 0.4970 - val_loss: 0.6931 - val_acc: 0.5000 - 53s/epoch - 529ms/step
# Epoch 7/15
# 100/100 - 53s - loss: 0.6932 - acc: 0.4980 - val_loss: 0.6931 - val_acc: 0.5000 - 53s/epoch - 535ms/step
# Epoch 8/15
# 100/100 - 53s - loss: 0.6932 - acc: 0.4960 - val_loss: 0.6931 - val_acc: 0.5000 - 53s/epoch - 533ms/step
# Epoch 9/15
# 100/100 - 53s - loss: 0.6932 - acc: 0.4850 - val_loss: 0.6931 - val_acc: 0.5000 - 53s/epoch - 534ms/step
# Epoch 10/15
# 100/100 - 56s - loss: 0.6932 - acc: 0.4920 - val_loss: 0.6931 - val_acc: 0.5000 - 56s/epoch - 559ms/step
# Epoch 11/15
# 100/100 - 53s - loss: 0.6932 - acc: 0.4970 - val_loss: 0.6931 - val_acc: 0.5000 - 53s/epoch - 530ms/step
# Epoch 12/15
# 100/100 - 52s - loss: 0.6932 - acc: 0.4850 - val_loss: 0.6931 - val_acc: 0.5000 - 52s/epoch - 520ms/step
# Epoch 13/15
# 100/100 - 52s - loss: 0.6932 - acc: 0.4910 - val_loss: 0.6931 - val_acc: 0.5000 - 52s/epoch - 519ms/step
# Epoch 14/15
# 100/100 - 52s - loss: 0.6932 - acc: 0.4910 - val_loss: 0.6931 - val_acc: 0.5000 - 52s/epoch - 517ms/step
# Epoch 15/15
# 100/100 - 53s - loss: 0.6932 - acc: 0.4890 - val_loss: 0.6931 - val_acc: 0.5000 - 53s/epoch - 529ms/step

# %% [markdown]
# ### (d) ###
# What is the last epoch training and validation accuracies (round off your answers to the nearest hundredth)?

# %% [markdown]
# ####Training Accuracy = 0.9915,  Validation Accuracy = 0.7270

# %% [markdown]
# ### (e) ###
# Plot the learning curves for accuracy and loss for your CNN training.

# %%
### YOUR CODE HERE ###
# Retrieve a list of accuracy results on training and test data
# sets for each training epoch
acc = history.history['acc']
val_acc = history.history['val_acc']

# Retrieve a list of list results on training and test data
# sets for each training epoch
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs = range(len(acc))

# Plot training and validation accuracy per epoch
plt.plot(epochs, acc)
plt.plot(epochs, val_acc)
plt.legend(['train', 'test'], loc='upper left')
plt.title('Training and validation accuracy')

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss)
plt.plot(epochs, val_loss)
plt.legend(['train', 'test'], loc='lower left')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# ### (f) ###
# Do these plots show signs of overfitting?   Why, or why not?

# %% [markdown]
# ####The plots show signs of overfitting because there is a point (around epoch 3) where the training data and testing data split away from each other as we train more.
